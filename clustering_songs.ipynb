# %%
from songcluster import cluster as cl
import pandas as pd

# %%
hot = pd.read_csv("hot_features.csv")

# %%
not_hot = pd.read_csv("not_hot_features.csv")

# %%
hot_and_not = pd.concat([not_hot, hot], axis=0)

# %%
scaled_hot_and_not, filename = cl.standard_scaler(hot_and_not, "songscaler")

# %%
display(scaled_hot_and_not)
# Out:
#        danceability    energy       key  loudness      mode  speechiness  \
# 0         -0.082824  0.114768  1.642342 -1.002052 -1.751229    -0.511611
# 1          1.074890  0.187750  0.228407 -0.740999 -1.751229     1.526466
# 2          1.167507  0.392100 -1.185529 -0.408198  0.571028     0.513991
# 3          1.359357  0.095306 -1.468316  0.212976  0.571028     4.857621
# 4          1.961368 -0.206353  1.359555  0.461335 -1.751229     3.101790
# ...             ...       ...       ...       ...       ...          ...
# 12049      1.392434 -1.451913 -1.468316 -0.292573 -1.751229    -0.186700
# 12050      0.373646  1.151113  1.642342  1.208344  0.571028    -0.357360
# 12051      1.260124  0.659701 -0.054380  1.566257 -1.751229    -0.196546
# 12052      0.929349 -0.439895  1.642342 -0.373428 -1.751229     7.007282
# 12053      0.009793  0.727817  1.359555  0.857882 -1.751229     4.988898
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# ...

# %%
cl.clustering(scaled_hot_and_not)
# Out:
# Training a K-Means model with 2 neighbours!
#
# Training a K-Means model with 3 neighbours!
#
# Training a K-Means model with 4 neighbours!
#
# Training a K-Means model with 5 neighbours!
#
# Training a K-Means model with 6 neighbours!
#
# Training a K-Means model with 7 neighbours!
#
# Training a K-Means model with 8 neighbours!
#
# Training a K-Means model with 9 neighbours!
#
# Training a K-Means model with 10 neighbours!
#
# Training a K-Means model with 11 neighbours!
#
# Training a K-Means model with 12 neighbours!
#
# Training a K-Means model with 13 neighbours!
#
# Training a K-Means model with 14 neighbours!
#
# Training a K-Means model with 15 neighbours!
#
# Training a K-Means model with 16 neighbours!
#
# Training a K-Means model with 17 neighbours!
#
# Training a K-Means model with 18 neighbours!
#
# Training a K-Means model with 19 neighbours!
#
# Training a K-Means model with 20 neighbours!

# %%
cl.predict(scaled_hot_and_not, hot_and_not, "kmeans_2_10.sav")
# Out:
#                                              songname  \
# 0                                   Solitude Standing
# 1                                               Heart
# 2                                  Kisses On The Wind
# 3                                     Player's Anthem
# 4   If I Ruled the World (Imagine That) (feat. Lau...
# ..                                                ...
# 48                                      Banking On Me
# 49                              GIVE HEAVEN SOME HELL
# 50                                              Bones
# 51                                      Pissed Me Off
# 52                                    I Hate YoungBoy
#
#                         artist              album  danceability  energy  key  \
# 0                 Suzanne Vega  Solitude Standing         0.570   0.630   11
# 1                 Neneh Cherry     Raw Like Sushi         0.745   0.645    6
# 2                 Neneh Cherry     Raw Like Sushi         0.759   0.687    1
# ...

# %%
cl.clustering_2(scaled_hot_and_not)
# Out:
# Training a K-Means model with 2 neighbours and 5 n!
#
# Training a K-Means model with 2 neighbours and 10 n!
#
# Training a K-Means model with 2 neighbours and 30 n!
#
# Training a K-Means model with 2 neighbours and 50 n!
#
# Training a K-Means model with 3 neighbours and 5 n!
#
# Training a K-Means model with 3 neighbours and 10 n!
#
# Training a K-Means model with 3 neighbours and 30 n!
#
# Training a K-Means model with 3 neighbours and 50 n!
#
# Training a K-Means model with 4 neighbours and 5 n!
#
# Training a K-Means model with 4 neighbours and 10 n!
#
# Training a K-Means model with 4 neighbours and 30 n!
#
# Training a K-Means model with 4 neighbours and 50 n!
#
# Training a K-Means model with 5 neighbours and 5 n!
#
# Training a K-Means model with 5 neighbours and 10 n!
#
# Training a K-Means model with 5 neighbours and 30 n!
#
# Training a K-Means model with 5 neighbours and 50 n!
#
# Training a K-Means model with 6 neighbours and 5 n!
#
# ...

# %%
cl.
